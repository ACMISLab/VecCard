# %%
import pandas as pd

# %%
df = pd.read_csv('F:\\LCE\\dataset\\business_mf.csv')

# %%
df
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150238  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150239  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150240  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150241  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150242  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state     code  stars  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA    93101    5.0
# 1       87 Grasso Plaza Shopping Center         Affton    MO    63123    3.0
# ...
